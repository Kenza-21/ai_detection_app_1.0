# %%
 # Cellule 1 - Imports et configuration
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
import joblib
import os
import pandas as pd
import numpy as np
import logging

# Configuration du logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Chemins des modèles
MODEL_DIR = "models"
MODEL_PATH = os.path.join(MODEL_DIR, "isolation_forest_v1.joblib")
SCALER_PATH = os.path.join(MODEL_DIR, "scaler_v1.joblib")

# Création du dossier models si inexistant
os.makedirs(MODEL_DIR, exist_ok=True)

# %%
import pandas as pd
import numpy as np

# Création de 100 transactions 100% normales
num_transactions = 100

normal_data = pd.DataFrame({
    'is_anomaly': [0] * num_transactions,
    'is_international': [False] * num_transactions,
    'intrbk_sttlm_amt': np.random.randint(500, 150000, num_transactions),
    'distance_km': np.random.randint(50, 600, num_transactions),
    'debtor_country': ['MA'] * num_transactions,
    'creditor_country': ['MA'] * num_transactions,
    'debtor_city': np.random.choice(['Casablanca', 'Rabat', 'Marrakech', 'Tanger'], num_transactions),
    'creditor_city': np.random.choice(['Casablanca', 'Rabat', 'Marrakech', 'Tanger'], num_transactions),
    'debtor_name': [f'CLIENT_NORMAL_{i}' for i in range(num_transactions)],
    'creditor_name': [f'FOURNISSEUR_NORMAL_{i}' for i in range(num_transactions)]
})

# Ingénierie des caractéristiques
normal_data['intrbk_sttlm_amt_log'] = np.log1p(normal_data['intrbk_sttlm_amt'])

print("Exemples de transactions 100% normales :")
print(normal_data.head())
# Out:
# Exemples de transactions 100% normales :
#    is_anomaly  is_international  intrbk_sttlm_amt  distance_km debtor_country  \
# 0           0             False             24682          591             MA
# 1           0             False             38545          380             MA
# 2           0             False              9553          155             MA
# 3           0             False            127425          144             MA
# 4           0             False              2510          141             MA
#
#   creditor_country debtor_city creditor_city      debtor_name  \
# 0               MA      Tanger         Rabat  CLIENT_NORMAL_0
# 1               MA       Rabat        Tanger  CLIENT_NORMAL_1
# 2               MA      Tanger         Rabat  CLIENT_NORMAL_2
# 3               MA      Tanger     Marrakech  CLIENT_NORMAL_3
# 4               MA  Casablanca     Marrakech  CLIENT_NORMAL_4
#
#           creditor_name  intrbk_sttlm_amt_log
# ...

# %%
from app.ml_model import FraudModel
from sklearn.preprocessing import StandardScaler
import joblib
import os

fraud_model = FraudModel()

# Vérification et création du scaler si nécessaire
if fraud_model.scaler is None:
    print("Création d'un nouveau scaler...")
    fraud_model.scaler = StandardScaler()
    # Utiliser data_train au lieu de train_df
    features = data_train[fraud_model.expected_features]
    fraud_model.scaler.fit(features)
    joblib.dump(fraud_model.scaler, SCALER_PATH)
    print(f"Scaler enregistré à {SCALER_PATH}")

# Entraînement du modèle

if fraud_model.model is None or not hasattr(fraud_model.model, 'estimators_'):
    print("Entraînement du modèle...")
    features = data_train[fraud_model.expected_features]
    
    # ✅ ne pas convertir en numpy, garder DataFrame
    scaled_features = fraud_model.scaler.transform(features) if fraud_model.scaler else features
    
    fraud_model.model = IsolationForest(contamination=0.01, random_state=42)
    fraud_model.model.fit(scaled_features)
    joblib.dump(fraud_model.model, MODEL_PATH)
    print(f"Modèle enregistré à {MODEL_PATH}")


# Vérification finale
print("\nÉtat des composants:")
print(f"- Scaler chargé: {fraud_model.scaler is not None}")
print(f"- Modèle chargé: {fraud_model.model is not None}")
if fraud_model.model is not None:
    print(f"- Modèle entraîné: {hasattr(fraud_model.model, 'estimators_')}")
# Out:
# État des composants:
# - Scaler chargé: True
# - Modèle chargé: True
# - Modèle entraîné: True

# %%
def prepare_for_detection(df, model):
    """Prépare les données pour la détection d'anomalies"""
    df = model.standardize_amount_column(df)
    
    # Vérification des features
    missing = [f for f in model.expected_features if f not in df.columns]
    if missing:
        available = [c for c in df.columns if c in model.expected_features]
        raise ValueError(
            f"Features manquantes: {missing}\n"
            f"Features disponibles: {available}\n"
            f"Features attendues: {model.expected_features}"
        )
    return df

try:
    # Préparation des données - utiliser data_train
    prepared_data = prepare_for_detection(data_train.copy(), fraud_model)
    
    # Détection des anomalies
    results = fraud_model.detect_anomalies(prepared_data)
    print("\n✅ Détection terminée avec succès")
    display(results.head())
    
except Exception as e:
    print("\n❌ Erreur:", str(e))
    print("Détails de débogage:")
    print(f"- Scaler disponible: {fraud_model.scaler is not None}")
    print(f"- Modèle disponible: {fraud_model.model is not None}")
    if fraud_model.model:
        print(f"- Modèle entraîné: {hasattr(fraud_model.model, 'estimators_')}")
# Out:
# ✅ Détection terminée avec succès
# c:\Users\Bellamine Kenza\Desktop\fraud_new\venv\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
# c:\Users\Bellamine Kenza\Desktop\fraud_new\venv\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
# c:\Users\Bellamine Kenza\Desktop\fraud_new\app\ml_model.py:224: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ True  True False ...  True  True  True]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'is_anomaly'] = (df['combined_score'] > 0.5) | (df['rule_based_anomaly'])
#    is_anomaly  intrbk_sttlm_amt  distance_km  is_international debtor_country  \
# ...

# %%
anomalies = results[results['is_anomaly'] == 1]
print(f"\nNombre d'anomalies détectées : {len(anomalies)}")

# Afficher un tableau complet avec les colonnes importantes
display(anomalies[['intrbk_sttlm_amt', 'debtor_country', 
                  'creditor_country', 'is_international', 'rule_based_score', 
                  'ai_score', 'combined_score']])
# Out:
# Nombre d'anomalies détectées : 573
#       intrbk_sttlm_amt debtor_country creditor_country  is_international  \
# 0                 2701             MA               MA             False
# 1                11675             MA               MA             False
# 9000            760799             MA               CN              True
# 9001            316050             MA               AE              True
# 9002            395681             MA               AE              True
# ...                ...            ...              ...               ...
# 9995              2472             NG               MA              True
# 9996              1223             SY               MA              True
# 9997              3507             NG               MA              True
# 9998              1294             SY               MA              True
# 9999              2006             IR               MA              True
#
#       rule_based_score  ai_score  combined_score
# ...

# %%
# Vérification des caractéristiques
print("Features attendues par le modèle:", fraud_model.expected_features)
print("\nFeatures disponibles dans data_train:")
print([col for col in data_train.columns if col in fraud_model.expected_features])

# Vérifier si les features nécessaires sont présentes
missing_features = [f for f in fraud_model.expected_features if f not in data_train.columns]
if missing_features:
    print(f"\n⚠️  Features manquantes: {missing_features}")
    print("Ajoutez ces colonnes à votre DataFrame:")
    
    # Suggestions pour ajouter les features manquantes
    if 'is_international' not in data_train.columns:
        print("- 'is_international': data_train['is_international'] = (data_train['debtor_country'] != data_train['creditor_country']).astype(int)")
    
    if 'intrbk_sttlm_amt_log' not in data_train.columns:
        print("- 'intrbk_sttlm_amt_log': data_train['intrbk_sttlm_amt_log'] = np.log1p(data_train['intrbk_sttlm_amt'])")
else:
    print("\n✅ Toutes les features nécessaires sont présentes")
# Out:
# Features attendues par le modèle: ['intrbk_sttlm_amt', 'intrbk_sttlm_amt_log', 'is_international']
#
# Features disponibles dans data_train:
# ['intrbk_sttlm_amt', 'is_international', 'intrbk_sttlm_amt_log']
#
# ✅ Toutes les features nécessaires sont présentes
