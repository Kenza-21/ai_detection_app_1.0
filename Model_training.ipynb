# %%
 # Cellule 1 - Imports et configuration
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
import joblib
import os
import pandas as pd
import numpy as np
import logging

# Configuration du logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Chemins des modèles
MODEL_DIR = "models"
MODEL_PATH = os.path.join(MODEL_DIR, "isolation_forest_v1.joblib")
SCALER_PATH = os.path.join(MODEL_DIR, "scaler_v1.joblib")

# Création du dossier models si inexistant
os.makedirs(MODEL_DIR, exist_ok=True)

# %%
# Importations nécessaires
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
import joblib
import os
import pandas as pd
import numpy as np
import logging
from app.customization import get_custom_rules  # IMPORTATION DE VOTRE SYSTÈME

# Configuration
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
MODEL_DIR = "models"
MODEL_PATH = os.path.join(MODEL_DIR, "isolation_forest_v1.joblib")
SCALER_PATH = os.path.join(MODEL_DIR, "scaler_v1.joblib")
os.makedirs(MODEL_DIR, exist_ok=True)

# AJOUTEZ CES FONCTIONS MÉTIER CRUCIALES
SECTOR_NORMS = {
    'INDUSTRIEL': {'min': 50000, 'max': 20000000},   # 50K-20M
    'DISTRIBUTION': {'min': 1000, 'max': 500000},    # 1K-500K
    'TEXTILE': {'min': 5000, 'max': 1000000},        # 5K-1M
    'SERVICES': {'min': 1000, 'max': 200000},        # 1K-200K
    'DEFAULT': {'min': 1000, 'max': 1000000}         # Valeur par défaut
}

def detect_sector(name1, name2):
    """Détecte le secteur d'activité basé sur les noms"""
    name = (str(name1) + ' ' + str(name2)).lower()
    
    if any(word in name for word in ['industr', 'atlas', 'matières', 'premières', 'usine', 'production']):
        return 'INDUSTRIEL'
    elif any(word in name for word in ['distrib', 'ventes', 'commerce', 'market', 'store']):
        return 'DISTRIBUTION'
    elif any(word in name for word in ['textile', 'habillement', 'vêtement', 'tissu', 'couture']):
        return 'TEXTILE'
    elif any(word in name for word in ['service', 'consulting', 'conseil', 'bureau', 'office']):
        return 'SERVICES'
    else:
        return 'DEFAULT'

def is_amount_normal(amount, debtor_name, creditor_name):
    """Vérifie si le montant est normal pour le secteur d'activité"""
    sector = detect_sector(debtor_name, creditor_name)
    norms = SECTOR_NORMS.get(sector, SECTOR_NORMS['DEFAULT'])
    
    return norms['min'] <= amount <= norms['max']

# Création des données d'entraînement AVEC INTELLIGENCE MÉTIER
def create_training_data():
    """Crée des données d'entraînement compatibles avec le système de personnalisation"""
    
    # CHARGER LES RÈGLES PERSONNALISÉES
    rules = get_custom_rules()
    blacklist_countries = rules.get('BLACKLIST_COUNTRIES', ['VG', 'KY', 'PA', 'TT', 'MU'])
    
    postal_codes_ma = {
        'Casablanca': '20000', 'Rabat': '10000', 'Marrakech': '40000',
        'Tanger': '90000', 'Fès': '30000', 'Agadir': '80000',
        'Oujda': '60000', 'Meknès': '50000', 'Kénitra': '14000',
        'Safi': '46000', 'El Jadida': '24000', 'Nador': '62000'
    }
    
    n_normal = 1000
    n_fraud = 200
    
    # Transactions normales - AVEC SECTEURS RÉALISTES
    normal_data = {
        'intrbk_sttlm_amt': np.concatenate([
            np.random.uniform(1000, 30000, n_normal//4),      # Services
            np.random.uniform(5000, 80000, n_normal//4),      # Textile
            np.random.uniform(10000, 200000, n_normal//4),    # Distribution
            np.random.uniform(50000, 5000000, n_normal//4)    # Industriel
        ]),
        'debtor_name': [
            *[f'SARL SERVICES {i}' for i in range(1, 251)],      # Services
            *[f'TEXTILES MAROC {i}' for i in range(1, 251)],     # Textile
            *[f'DISTRIBUTION {i}' for i in range(1, 251)],       # Distribution
            *[f'GROUPE INDUSTRIEL {i}' for i in range(1, 251)]   # Industriel
        ],
        'creditor_name': [
            *[f'FOURNISSEUR SERVICES {i}' for i in range(1, 251)],
            *[f'APPROV TEXTILE {i}' for i in range(1, 251)],
            *[f'CLIENT DISTRIB {i}' for i in range(1, 251)],
            *[f'MATIERES PREMIERES {i}' for i in range(1, 251)]
        ],
        'debtor_country': ['MA'] * n_normal,
        'creditor_country': ['MA'] * (n_normal - 100) + ['FR'] * 50 + ['ES'] * 30 + ['US'] * 20,
        'debtor_city': np.random.choice(list(postal_codes_ma.keys()), n_normal),
        'creditor_city': np.random.choice(list(postal_codes_ma.keys()), n_normal),
        'distance_km': np.random.uniform(5, 500, n_normal),
    }
    
    # Transactions frauduleuses - AVEC SECTEURS RÉALISTES MAIS COMPORTEMENTS ANORMAUX
    countries = ['MA'] + blacklist_countries
    probs = [0.3] + [0.7 / len(blacklist_countries)] * len(blacklist_countries)
    
    fraud_data = {
        'intrbk_sttlm_amt': np.concatenate([
            np.random.uniform(500000, 2000000, n_fraud//2),      # Montants très élevés
            np.random.uniform(1, 100, n_fraud//4),               # Montants très faibles
            np.random.uniform(50000, 150000, n_fraud//4)         # Montants suspects
        ]),
        'debtor_name': [
            *['COMPAGNIE SUSPECTE'] * (n_fraud//2),
            *['SOCIETE OMNI'] * (n_fraud//2)
        ],
        'creditor_name': [
            *['BENEFICIAIRE OFFSHORE'] * (n_fraud//2),
            *['SERVICES INTER'] * (n_fraud//2)
        ],
        'debtor_country': ['MA'] * n_fraud,
        'creditor_country': np.random.choice(countries, n_fraud, p=probs),
        'debtor_city': ['Casablanca'] * n_fraud,
        'creditor_city': ['Casablanca'] * n_fraud,
        'distance_km': [0.0] * (n_fraud//2) + list(np.random.uniform(0, 10, n_fraud//2)),
    }
    
    # Combiner les données
    all_data = {}
    for key in normal_data.keys():
        all_data[key] = list(normal_data[key]) + list(fraud_data[key])
    
    # Créer le DataFrame
    df = pd.DataFrame(all_data)
    
    # Features supplémentaires
    df['intrbk_sttlm_amt_log'] = np.log1p(df['intrbk_sttlm_amt'])
    df['is_international'] = (df['debtor_country'] != df['creditor_country']).astype(int)
    
    # Label initial
    df['is_fraud'] = [0] * n_normal + [1] * n_fraud
    
    
    return df

# ---- Entraînement du modèle ----
data_train = create_training_data()
print(f"Données d'entraînement créées: {len(data_train)} transactions")
print(f"Nombre de fraudes après correction métier: {data_train['is_fraud'].sum()}")

expected_features = ['intrbk_sttlm_amt_log', 'is_international', 'distance_km']

X_train = data_train[expected_features]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_train)

# Modifiez l'entraînement du modèle :
model = IsolationForest(
    contamination=0.03,  # ⬇️ Encore plus conservateur (était 0.05)
    random_state=42,
    max_samples=0.7,
    max_features=0.9,    # ⬆️ Utiliser plus de features
    n_estimators=150     # ⬆️ Plus d'arbres pour plus de stabilité
)
model.fit(X_scaled)

joblib.dump(model, MODEL_PATH)
joblib.dump(scaler, SCALER_PATH)

print(f"Modèle sauvegardé: {MODEL_PATH}")
print(f"Scaler sauvegardé: {SCALER_PATH}")
# Out:
# Données d'entraînement créées: 1200 transactions
# Nombre de fraudes après correction métier: 200
# Modèle sauvegardé: models\isolation_forest_v1.joblib
# Scaler sauvegardé: models\scaler_v1.joblib

# %%
# Importations nécessaires
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import joblib
import os
import pandas as pd
import numpy as np
import logging
from app.customization import get_custom_rules

# Configuration
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
MODEL_DIR = "models"
MODEL_PATH = os.path.join(MODEL_DIR, "isolation_forest_v1.joblib")
SCALER_PATH = os.path.join(MODEL_DIR, "scaler_v1.joblib")
os.makedirs(MODEL_DIR, exist_ok=True)

# Fonctions métier
SECTOR_NORMS = {
    'INDUSTRIEL': {'min': 50000, 'max': 20000000},
    'DISTRIBUTION': {'min': 1000, 'max': 500000},
    'TEXTILE': {'min': 5000, 'max': 1000000},
    'SERVICES': {'min': 1000, 'max': 200000},
    'DEFAULT': {'min': 1000, 'max': 1000000}
}

def detect_sector(name1, name2):
    name = (str(name1) + ' ' + str(name2)).lower()
    if any(word in name for word in ['industr', 'atlas', 'matières', 'premières', 'usine', 'production']):
        return 'INDUSTRIEL'
    elif any(word in name for word in ['distrib', 'ventes', 'commerce', 'market', 'store']):
        return 'DISTRIBUTION'
    elif any(word in name for word in ['textile', 'habillement', 'vêtement', 'tissu', 'couture']):
        return 'TEXTILE'
    elif any(word in name for word in ['service', 'consulting', 'conseil', 'bureau', 'office']):
        return 'SERVICES'
    else:
        return 'DEFAULT'

def is_amount_normal(amount, debtor_name, creditor_name):
    sector = detect_sector(debtor_name, creditor_name)
    norms = SECTOR_NORMS.get(sector, SECTOR_NORMS['DEFAULT'])
    return norms['min'] <= amount <= norms['max']

def create_training_data():
    rules = get_custom_rules()
    blacklist_countries = rules.get('BLACKLIST_COUNTRIES', ['VG', 'KY', 'PA', 'TT', 'MU'])
    
    postal_codes_ma = {
        'Casablanca': '20000', 'Rabat': '10000', 'Marrakech': '40000',
        'Tanger': '90000', 'Fès': '30000', 'Agadir': '80000',
        'Oujda': '60000', 'Meknès': '50000', 'Kénitra': '14000',
        'Safi': '46000', 'El Jadida': '24000', 'Nador': '62000'
    }
    
    n_normal = 1000
    n_fraud = 200
    
    # Transactions normales
    normal_data = {
        'intrbk_sttlm_amt': np.concatenate([
            np.random.uniform(1000, 30000, n_normal//4),
            np.random.uniform(5000, 80000, n_normal//4),
            np.random.uniform(10000, 200000, n_normal//4),
            np.random.uniform(50000, 5000000, n_normal//4)
        ]),
        'debtor_name': [
            *[f'SARL SERVICES {i}' for i in range(1, 251)],
            *[f'TEXTILES MAROC {i}' for i in range(1, 251)],
            *[f'DISTRIBUTION {i}' for i in range(1, 251)],
            *[f'GROUPE INDUSTRIEL {i}' for i in range(1, 251)]
        ],
        'creditor_name': [
            *[f'FOURNISSEUR SERVICES {i}' for i in range(1, 251)],
            *[f'APPROV TEXTILE {i}' for i in range(1, 251)],
            *[f'CLIENT DISTRIB {i}' for i in range(1, 251)],
            *[f'MATIERES PREMIERES {i}' for i in range(1, 251)]
        ],
        'debtor_country': ['MA'] * n_normal,
        'creditor_country': ['MA'] * (n_normal - 100) + ['FR'] * 50 + ['ES'] * 30 + ['US'] * 20,
        'debtor_city': np.random.choice(list(postal_codes_ma.keys()), n_normal),
        'creditor_city': np.random.choice(list(postal_codes_ma.keys()), n_normal),
        'distance_km': np.random.uniform(5, 500, n_normal),
    }
    
    # Transactions frauduleuses
    countries = ['MA'] + blacklist_countries
    probs = [0.3] + [0.7 / len(blacklist_countries)] * len(blacklist_countries)
    
    fraud_data = {
        'intrbk_sttlm_amt': np.concatenate([
            np.random.uniform(500000, 2000000, n_fraud//2),
            np.random.uniform(1, 100, n_fraud//4),
            np.random.uniform(50000, 150000, n_fraud//4)
        ]),
        'debtor_name': [
            *['COMPAGNIE SUSPECTE'] * (n_fraud//2),
            *['SOCIETE OMNI'] * (n_fraud//2)
        ],
        'creditor_name': [
            *['BENEFICIAIRE OFFSHORE'] * (n_fraud//2),
            *['SERVICES INTER'] * (n_fraud//2)
        ],
        'debtor_country': ['MA'] * n_fraud,
        'creditor_country': np.random.choice(countries, n_fraud, p=probs),
        'debtor_city': ['Casablanca'] * n_fraud,
        'creditor_city': ['Casablanca'] * n_fraud,
        'distance_km': [0.0] * (n_fraud//2) + list(np.random.uniform(0, 10, n_fraud//2)),
    }
    
    # Combiner les données
    all_data = {}
    for key in normal_data.keys():
        all_data[key] = list(normal_data[key]) + list(fraud_data[key])
    
    df = pd.DataFrame(all_data)
    df['intrbk_sttlm_amt_log'] = np.log1p(df['intrbk_sttlm_amt'])
    df['is_international'] = (df['debtor_country'] != df['creditor_country']).astype(int)
    df['is_fraud'] = [0] * n_normal + [1] * n_fraud
    
    return df

# Fonction pour appliquer les règles personnalisées
def apply_custom_rules(df, rules_config):
    df['rule_based_anomaly'] = 0
    blacklist_countries = rules_config.get('BLACKLIST_COUNTRIES', ['VG', 'KY', 'PA', 'TT', 'MU'])
    
    df.loc[df['intrbk_sttlm_amt'] > 500000, 'rule_based_anomaly'] = 1
    df.loc[df['creditor_country'].isin(blacklist_countries), 'rule_based_anomaly'] = 1
    df.loc[(df['is_international'] == 1) & (df['intrbk_sttlm_amt'] > 100000), 'rule_based_anomaly'] = 1
    
    df['final_anomaly'] = ((df['is_anomaly'] == 1) | (df['rule_based_anomaly'] == 1)).astype(int)
    return df

# --- DÉBUT DE L'EXÉCUTION ---
print("🔄 Création des données d'entraînement...")
data_train = create_training_data()
print(f"✅ Données créées: {len(data_train)} transactions, {data_train['is_fraud'].sum()} fraudes")

# 🔁 DIVISION TRAIN/TEST
X = data_train[['intrbk_sttlm_amt_log', 'is_international', 'distance_km']]
y = data_train['is_fraud']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

print(f"📊 Train set: {len(X_train)} transactions, {y_train.sum()} fraudes")
print(f"📊 Test set: {len(X_test)} transactions, {y_test.sum()} fraudes")

# 🎯 ENTRAÎNEMENT
print("🔄 Entraînement du modèle...")
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Augmentez la spécificité du modèle AI
model = IsolationForest(
    contamination=0.02,  # ⬇️ Encore plus conservateur
    random_state=42,
    max_samples=0.8,
    max_features=1.0,    # Utiliser toutes les features
    n_estimators=200,    # Plus d'arbres
    bootstrap=True       # Échantillonnage bootstrap
)
model.fit(X_train_scaled)

# 💾 SAUVEGARDE
joblib.dump(model, MODEL_PATH)
joblib.dump(scaler, SCALER_PATH)
print(f"💾 Modèle sauvegardé: {MODEL_PATH}")

# 🧪 ÉVALUATION SUR TEST SET
print("🧪 Évaluation sur test set...")
X_test_scaled = scaler.transform(X_test)
test_predictions = model.predict(X_test_scaled)
test_anomalies = [1 if x == -1 else 0 for x in test_predictions]

print("📈 PERFORMANCE AI SEULE (test set):")
print(classification_report(y_test, test_anomalies))
print(confusion_matrix(y_test, test_anomalies))

# 🎯 APPLICATION DES RÈGLES PERSONNALISÉES
print("🔧 Application des règles personnalisées...")
rules = get_custom_rules()
test_df = data_train.iloc[X_test.index].copy()
test_df['is_anomaly'] = test_anomalies
test_df = apply_custom_rules(test_df, rules)

print("🎯 PERFORMANCE FINALE AVEC RÈGLES (test set):")
print(classification_report(test_df['is_fraud'], test_df['final_anomaly']))
print(confusion_matrix(test_df['is_fraud'], test_df['final_anomaly']))

# 📊 STATISTIQUES FINALES
final_detected = test_df[test_df['final_anomaly'] == 1]
frauds_caught = final_detected[final_detected['is_fraud'] == 1]
false_positives = final_detected[final_detected['is_fraud'] == 0]

print(f"\n✅ PERFORMANCE RÉELLE:")
print(f"   Fraudes détectées: {len(frauds_caught)}/{y_test.sum()}")
print(f"   Faux positifs: {len(false_positives)}")
print(f"   Taux de détection: {len(frauds_caught)/y_test.sum()*100:.1f}%")
print(f"   Taux de faux positifs: {len(false_positives)/len(X_test)*100:.1f}%")

print("\n🎯 Configuration utilisée:")
print(f"   Pays blacklistés: {rules.get('BLACKLIST_COUNTRIES', [])}")

print("\n🚀 ENTRAÎNEMENT TERMINÉ AVEC SUCCÈS!")
# Out:
# 🔄 Création des données d'entraînement...
# ✅ Données créées: 1200 transactions, 200 fraudes
# 📊 Train set: 840 transactions, 140 fraudes
# 📊 Test set: 360 transactions, 60 fraudes
# 🔄 Entraînement du modèle...
# 💾 Modèle sauvegardé: models\isolation_forest_v1.joblib
# 🧪 Évaluation sur test set...
# 📈 PERFORMANCE AI SEULE (test set):
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       300
#            1       0.67      0.03      0.06        60
#
#     accuracy                           0.84       360
#    macro avg       0.75      0.52      0.49       360
# weighted avg       0.81      0.84      0.77       360
#
# [[299   1]
#  [ 58   2]]
# 🔧 Application des règles personnalisées...
# 🎯 PERFORMANCE FINALE AVEC RÈGLES (test set):
#               precision    recall  f1-score   support
#
#            0       0.98      0.75      0.85       300
#            1       0.43      0.93      0.59        60
#
# ...

# %%
# Cellule 3 - Préparation et test de détection
def prepare_for_detection(df, model):
    """Prépare les données pour la détection d'anomalies"""
    df = model.standardize_amount_column(df)
    
    # Vérification des features
    missing = [f for f in model.expected_features if f not in df.columns]
    if missing:
        available = [c for c in df.columns if c in model.expected_features]
        raise ValueError(
            f"Features manquantes: {missing}\n"
            f"Features disponibles: {available}\n"
            f"Features attendues: {model.expected_features}"
        )
    return df

try:
    # Préparation des données
    prepared_data = prepare_for_detection(data_train.copy(), fraud_model)
    
    # Détection des anomalies
    results = fraud_model.detect_anomalies(prepared_data)
    print("\n✅ Détection terminée avec succès")
    
    # Afficher les résultats pour la transaction normale spécifique
    normal_transaction = results[
        (results['debtor_name'] == 'ENTREPRISE B') & 
        (results['creditor_name'] == 'FOURNISSEUR LOCAL') &
        (results['intrbk_sttlm_amt'] == 12000.00)
    ]
    
    if not normal_transaction.empty:
        print("\nTransaction normale détectée:")
        print(f"Score de risque: {normal_transaction['combined_score'].iloc[0] * 100:.1f}%")
        print(f"Anomaly: {normal_transaction['is_anomaly'].iloc[0]}")
    else:
        print("\nTransaction normale non trouvée dans les résultats")
    
    display(results.head())
    
except Exception as e:
    print("\n❌ Erreur:", str(e))
    print("Détails de débogage:")
    print(f"- Scaler disponible: {fraud_model.scaler is not None}")
    print(f"- Modèle disponible: {fraud_model.model is not None}")
    if fraud_model.model:
        print(f"- Modèle entraîné: {hasattr(fraud_model.model, 'estimators_')}")
# Out:
# c:\Users\Bellamine Kenza\Desktop\fraud_new\app\ml_model.py:131: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'is_international'] = (df['debtor_country'] != df['creditor_country'])
# Ville: Casablanca, Pays: MA -> Coordonnées: 33.5945144, -7.6200284
# Code postal trouvé pour Casablanca: 20032
# Ville: Rabat, Pays: MA -> Coordonnées: 34.0218454, -6.8408929
# Code postal trouvé pour Rabat: 10115
# ...

# %%
anomalies = normal_transaction[normal_transaction['is_anomaly'] == 1]
print(f"\nNombre d'anomalies détectées : {len(anomalies)}")

# Afficher un tableau complet avec les colonnes importantes
display(anomalies[['intrbk_sttlm_amt', 'debtor_country', 
                  'creditor_country', 'is_international', 'rule_based_score', 
                  'ai_score', 'combined_score']])
# Out:
# Nombre d'anomalies détectées : 0
# Empty DataFrame
# Columns: [intrbk_sttlm_amt, debtor_country, creditor_country, is_international, rule_based_score, ai_score, combined_score]
# Index: []

# %%
# Vérification des caractéristiques
print("Features attendues par le modèle:", fraud_model.expected_features)
print("\nFeatures disponibles dans data_train:")
print([col for col in data_train.columns if col in fraud_model.expected_features])

# Vérifier si les features nécessaires sont présentes
missing_features = [f for f in fraud_model.expected_features if f not in data_train.columns]
if missing_features:
    print(f"\n⚠️  Features manquantes: {missing_features}")
    print("Ajoutez ces colonnes à votre DataFrame:")
    
    # Suggestions pour ajouter les features manquantes
    if 'is_international' not in data_train.columns:
        print("- 'is_international': data_train['is_international'] = (data_train['debtor_country'] != data_train['creditor_country']).astype(int)")
    
    if 'intrbk_sttlm_amt_log' not in data_train.columns:
        print("- 'intrbk_sttlm_amt_log': data_train['intrbk_sttlm_amt_log'] = np.log1p(data_train['intrbk_sttlm_amt'])")
else:
    print("\n✅ Toutes les features nécessaires sont présentes")
# Out:
# Features attendues par le modèle: ['intrbk_sttlm_amt', 'intrbk_sttlm_amt_log', 'is_international']
#
# Features disponibles dans data_train:
# ['intrbk_sttlm_amt', 'is_international', 'intrbk_sttlm_amt_log']
#
# ✅ Toutes les features nécessaires sont présentes
