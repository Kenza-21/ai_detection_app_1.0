# %%
 # Cellule 1 - Imports et configuration
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
import joblib
import os
import pandas as pd
import numpy as np
import logging

# Configuration du logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Chemins des modèles
MODEL_DIR = "models"
MODEL_PATH = os.path.join(MODEL_DIR, "isolation_forest_v1.joblib")
SCALER_PATH = os.path.join(MODEL_DIR, "scaler_v1.joblib")

# Création du dossier models si inexistant
os.makedirs(MODEL_DIR, exist_ok=True)

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# --- 1. Création de transactions normales (Maroc) ---
# Liste des banques marocaines courantes et leurs codes fictifs
maroc_banks = {
    'Attijariwafa Bank': '007',
    'Banque Populaire': '145',
    'BMCE Bank of Africa': '011',
    'Crédit Agricole du Maroc': '230',
    'Société Générale Maroc': '325',
    'Crédit du Maroc': '212',
    'CIH Bank': '144'
}

# Liste des villes majeures au Maroc
maroc_cities = ['Casablanca', 'Rabat', 'Marrakech', 'Fès', 'Tanger', 'Agadir', 'Oujda', 'Tétouan']

num_normal = 9000

# Générer les transactions normales avec des caractéristiques spécifiques au Maroc
normal_data = pd.DataFrame({
    'is_anomaly': [0] * num_normal,
    # Simulation de montants normaux : petits achats, salaires, transactions d'entreprise
    'intrbk_sttlm_amt': np.random.choice(
        [np.random.randint(200, 5000), np.random.randint(5000, 50000), np.random.randint(50000, 250000)],
        p=[0.6, 0.3, 0.1],
        size=num_normal
    ),
    # Transactions nationales, donc la distance est limitée
    'distance_km': np.random.randint(50, 800, num_normal),
    'is_international': [False] * num_normal,
    'debtor_country': ['MA'] * num_normal,
    'creditor_country': ['MA'] * num_normal,
    'debtor_city': np.random.choice(maroc_cities, num_normal),
    'creditor_city': np.random.choice(maroc_cities, num_normal),
    'debtor_name': [f'CLIENT_NORMAL_{i}' for i in range(num_normal)],
    'creditor_name': [f'FOURNISSEUR_NORMAL_{i}' for i in range(num_normal)],
    'transaction_date': [datetime.now() - timedelta(days=np.random.randint(1, 365), seconds=np.random.randint(1, 86400)) for _ in range(num_normal)]
})
# Ajout des banques de manière aléatoire
normal_data['debtor_bank'] = np.random.choice(list(maroc_banks.keys()), num_normal)
normal_data['creditor_bank'] = np.random.choice(list(maroc_banks.keys()), num_normal)

# --- 2. Création de transactions anormales (1000 transactions) ---
num_anomalies = 1000

# Scénario 1: Transactions internationales à haute valeur
high_value_international = pd.DataFrame({
    'is_anomaly': [1] * 300,
    'intrbk_sttlm_amt': np.random.randint(250000, 1000000, 300),
    'distance_km': np.random.randint(5000, 15000, 300),
    'is_international': [True] * 300,
    'transaction_date': [datetime.now() - timedelta(days=np.random.randint(1, 365), seconds=np.random.randint(1, 86400)) for _ in range(300)]
})
high_value_international['debtor_country'] = 'MA'
high_value_international['creditor_country'] = np.random.choice(['JP', 'CN', 'RU', 'AE'], 300)
high_value_international['debtor_city'] = 'Casablanca'
high_value_international['creditor_city'] = high_value_international['creditor_country'].apply(lambda x: 'Tokyo' if x == 'JP' else 'Pékin' if x == 'CN' else 'Moscou' if x == 'RU' else 'Dubaï')
high_value_international['debtor_name'] = [f'ANOMALY_CLIENT_{i}' for i in range(300)]
high_value_international['creditor_name'] = [f'ANOMALY_FOURNISSEUR_{i}' for i in range(300)]

# Scénario 2: Montants anormalement élevés (même en national)
high_value_local = pd.DataFrame({
    'is_anomaly': [1] * 350,
    'intrbk_sttlm_amt': np.random.randint(200000, 800000, 350),
    'distance_km': np.random.randint(50, 600, 350),
    'is_international': [False] * 350,
    'transaction_date': [datetime.now() - timedelta(days=np.random.randint(1, 365), seconds=np.random.randint(1, 86400)) for _ in range(350)]
})
high_value_local['debtor_country'] = 'MA'
high_value_local['creditor_country'] = 'MA'
high_value_local['debtor_city'] = np.random.choice(['Casablanca', 'Rabat'], 350)
high_value_local['creditor_city'] = np.random.choice(['Marrakech', 'Tanger'], 350)
high_value_local['debtor_name'] = [f'ANOMALY_CLIENT_{i+300}' for i in range(350)]
high_value_local['creditor_name'] = [f'ANOMALY_FOURNISSEUR_{i+300}' for i in range(350)]

# Scénario 3: Transactions de faible montant mais à partir d'un pays "à risque"
low_value_risky_country = pd.DataFrame({
    'is_anomaly': [1] * 350,
    'intrbk_sttlm_amt': np.random.randint(1000, 5000, 350),
    'distance_km': np.random.randint(2000, 10000, 350),
    'is_international': [True] * 350,
    'transaction_date': [datetime.now() - timedelta(days=np.random.randint(1, 365), seconds=np.random.randint(1, 86400)) for _ in range(350)]
})
low_value_risky_country['debtor_country'] = np.random.choice(['NG', 'IR', 'SY'], 350)
low_value_risky_country['creditor_country'] = 'MA'
low_value_risky_country['debtor_city'] = low_value_risky_country['debtor_country'].apply(lambda x: 'Lagos' if x == 'NG' else 'Téhéran' if x == 'IR' else 'Damas' if x == 'SY' else 'Autre')
low_value_risky_country['creditor_city'] = 'Casablanca'
low_value_risky_country['debtor_name'] = [f'ANOMALY_CLIENT_{i+650}' for i in range(350)]
low_value_risky_country['creditor_name'] = [f'ANOMALY_FOURNISSEUR_{i+650}' for i in range(350)]

# Concaténer les données anormales
anomalous_data = pd.concat([high_value_international, high_value_local, low_value_risky_country], ignore_index=True)

# --- 3. Combinaison et nettoyage des données ---
data_train = pd.concat([normal_data, anomalous_data], ignore_index=True)

# Ingénierie des caractéristiques pour le jeu de données combiné
data_train['intrbk_sttlm_amt_log'] = np.log1p(data_train['intrbk_sttlm_amt'])
data_train['transaction_hour'] = data_train['transaction_date'].dt.hour
data_train['day_of_week'] = data_train['transaction_date'].dt.dayofweek

print("Répartition des classes dans le nouveau jeu de données :")
print(data_train['is_anomaly'].value_counts())
print("\nExemple de transactions normales :")
print(data_train[data_train['is_anomaly'] == 0].head())
print("\nExemple de transactions anormales :")
print(data_train[data_train['is_anomaly'] == 1].head())
# Out:
# Répartition des classes dans le nouveau jeu de données :
# is_anomaly
# 0    9000
# 1    1000
# Name: count, dtype: int64
#
# Exemple de transactions normales :
#    is_anomaly  intrbk_sttlm_amt  distance_km  is_international debtor_country  \
# 0           0              2114          187             False             MA
# 1           0              2114          215             False             MA
# 2           0              2114          205             False             MA
# 3           0             36827          574             False             MA
# 4           0             36827          554             False             MA
#
#   creditor_country debtor_city creditor_city      debtor_name  \
# 0               MA       Oujda         Rabat  CLIENT_NORMAL_0
# 1               MA      Tanger        Agadir  CLIENT_NORMAL_1
# 2               MA       Oujda    Casablanca  CLIENT_NORMAL_2
# 3               MA         Fès     Marrakech  CLIENT_NORMAL_3
# ...

# %%
from app.ml_model import FraudModel  # Import de votre classe

fraud_model = FraudModel()

# Vérification et création du scaler si nécessaire
if fraud_model.scaler is None:
    print("Création d'un nouveau scaler...")
    fraud_model.scaler = StandardScaler()
    features = train_df[fraud_model.expected_features]
    fraud_model.scaler.fit(features)
    joblib.dump(fraud_model.scaler, SCALER_PATH)
    print(f"Scaler enregistré à {SCALER_PATH}")

# Entraînement du modèle
if fraud_model.model is None or not hasattr(fraud_model.model, 'estimators_'):
    print("Entraînement du modèle...")
    features = train_df[fraud_model.expected_features]
    scaled_features = fraud_model.scaler.transform(features) if fraud_model.scaler else features
    
    fraud_model.model = IsolationForest(contamination=0.01, random_state=42)
    fraud_model.model.fit(scaled_features)
    joblib.dump(fraud_model.model, MODEL_PATH)
    print(f"Modèle enregistré à {MODEL_PATH}")

# Vérification finale
print("\nÉtat des composants:")
print(f"- Scaler chargé: {fraud_model.scaler is not None}")
print(f"- Modèle chargé: {fraud_model.model is not None}")
if fraud_model.model is not None:
    print(f"- Modèle entraîné: {hasattr(fraud_model.model, 'estimators_')}")
# Out:
# État des composants:
# - Scaler chargé: True
# - Modèle chargé: True
# - Modèle entraîné: True

# %%
def prepare_for_detection(df, model):
    """Prépare les données pour la détection d'anomalies"""
    df = model.standardize_amount_column(df)
    
    # Vérification des features
    missing = [f for f in model.expected_features if f not in df.columns]
    if missing:
        available = [c for c in df.columns if c in model.expected_features]
        raise ValueError(
            f"Features manquantes: {missing}\n"
            f"Features disponibles: {available}\n"
            f"Features attendues: {model.expected_features}"
        )
    return df

try:
    # Préparation des données
    train_df = prepare_for_detection(train_df, fraud_model)
    
    # Détection des anomalies
    results = fraud_model.detect_anomalies(train_df)
    print("\n✅ Détection terminée avec succès")
    display(results.head())
    
except Exception as e:
    print("\n❌ Erreur:", str(e))
    print("Détails de débogage:")
    print(f"- Scaler disponible: {fraud_model.scaler is not None}")
    print(f"- Modèle disponible: {fraud_model.model is not None}")
    if fraud_model.model:
        print(f"- Modèle entraîné: {hasattr(fraud_model.model, 'estimators_')}")
# Out:
# ✅ Détection terminée avec succès
# c:\Users\Bellamine Kenza\Desktop\fraud_new\venv\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
# c:\Users\Bellamine Kenza\Desktop\fraud_new\venv\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#    is_anomaly  intrbk_sttlm_amt  distance_km debtor_country creditor_country  \
# 0        True            850000        12000             FR               MA
# 1        True           1500000        15000             FR               MA
# 2        True            750000        10500             FR               MA
# 3        True           1200000        13000             FR               MA
# 4        True            950000        11500             FR               MA
#
# ...

# %%
anomalies = results[results['is_anomaly'] == 1]
print(f"\nNombre d'anomalies détectées : {len(anomalies)}")

# Afficher un tableau complet avec les colonnes importantes
display(anomalies[['intrbk_sttlm_amt', 'debtor_country', 
                  'creditor_country', 'is_international', 'rule_based_score', 
                  'ai_score', 'combined_score']])
# Out:
# Nombre d'anomalies détectées : 18
#     intrbk_sttlm_amt debtor_country creditor_country  is_international  \
# 0             850000             FR               MA              True
# 1            1500000             FR               MA              True
# 2             750000             FR               MA              True
# 3            1200000             FR               MA              True
# 4             950000             FR               MA              True
# 5            2500000             FR               MA              True
# 6            1800000             FR               MA              True
# 7            3000000             FR               MA              True
# 8            2200000             FR               MA              True
# 9            1950000             FR               MA              True
# 14             78000             US               MA              True
# 19             20500             US               MA              True
# ...
